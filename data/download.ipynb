# %%
from datasets import load_dataset
ds = load_dataset("qwedsacf/competition_math")

# Inspect loaded dataset
print(ds)

# Save to disk for later use in the notebook
ds.save_to_disk("competition_math_dataset")
print("Dataset saved to ./competition_math_dataset")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from datasets import load_dataset
# ----> 2 ds = load_dataset("qwedsacf/competition_math")
#       4 # Inspect loaded dataset
#       5 print(ds)
#
# File ~/work/assignment5-alignment/.venv/lib/python3.12/site-packages/datasets/load.py:2149, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2145 # Build dataset for splits
#    2146 keep_in_memory = (
#    2147     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2148 )
# ...
